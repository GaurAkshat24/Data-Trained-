# %%
import numpy as np 
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/dataset1/master/titanic_train.csv')

# %%
pd.set_option('Display.max_rows',None)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe().columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
df_num = df[['Age','SibSp','Parch','Fare']]
df_cat = df[['Survived','Pclass','Sex','Ticket','Cabin','Embarked']]

# %%
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
print(df.corr())
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
plt.figure(figsize=[40,30])
plt.title('Correlation')
sns.heatmap(df.corr(),cmap='twilight',annot=True)
plt.show()

# %%
for i in df_cat.columns:
    sns.barplot(df_cat[i].value_counts().index,df_cat[i].value_counts()).set_title(i)
    plt.show()

# %%
x = df.drop(['Cabin'], axis = 1)
y = df.drop(['Cabin'], axis = 1)

# %%
x = df.drop(['Ticket'], axis = 1)
y = df.drop(['Ticket'], axis = 1)

# %%
print("Number of people embarking in Southampton (S):")
southampton = df[df["Embarked"] == "S"].shape[0]
print(southampton)

print("Number of people embarking in Cherbourg (C):")
cherbourg = df[df["Embarked"] == "C"].shape[0]
print(cherbourg)

print("Number of people embarking in Queenstown (Q):")
queenstown = df[df["Embarked"] == "Q"].shape[0]
print(queenstown)
# Out:
# Number of people embarking in Southampton (S):
# 644
# Number of people embarking in Cherbourg (C):
# 168
# Number of people embarking in Queenstown (Q):
# 77

# %%
x = df.fillna({"Embarked": "S"})

# %%
combine = [x, y]
for df in combine:
    df['PassengerId'] = df.Name.str.extract(' ([A-Za-z]+)\.', expand=False)

pd.crosstab(train['PassengerId'], train['Sex'])
# Out:
# Sex          female  male
# PassengerId
# 1                 0     1
# 2                 1     0
# 3                 1     0
# 4                 1     0
# 5                 0     1
# 6                 0     1
# 7                 0     1
# 8                 0     1
# 9                 1     0
# 10                1     0
# 11                1     0
# 12                1     0
# 13                0     1
# 14                0     1
# 15                1     0
# 16                1     0
# 17                0     1
# 18                0     1
# 19                1     0
# 20                1     0
# 21                0     1
# 22                0     1
# 23                1     0
# 24                0     1
# 25                1     0
# 26                1     0
# 27                0     1
# 28                0     1
# 29                1     0
# 30                0     1
# 31                0     1
# 32                1     0
# 33                1     0
# 34                0     1
# ...

# %%
for df in combine:
    df['PassengerId'] = df['PassengerId'].replace(['Lady', 'Capt', 'Col',
    'Don', 'Dr', 'Major', 'Rev', 'Jonkheer', 'Dona'], 'Rare')
    
    df['PassengerId'] = df['PassengerId'].replace(['Countess', 'Lady', 'Sir'], 'Royal')
    df['PassengerId'] = df['PassengerId'].replace('Mlle', 'Miss')
    df['PassengerId'] = df['PassengerId'].replace('Ms', 'Miss')
    df['PassengerId'] = df['PassengerId'].replace('Mme', 'Mrs')

train[['PassengerId', 'Survived']].groupby(['PassengerId'], as_index=False).mean()
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# 5              6         0
# 6              7         0
# 7              8         0
# 8              9         1
# 9             10         1
# 10            11         1
# 11            12         1
# 12            13         0
# 13            14         0
# 14            15         0
# 15            16         1
# 16            17         0
# 17            18         1
# 18            19         0
# 19            20         1
# 20            21         0
# 21            22         1
# 22            23         1
# 23            24         1
# 24            25         0
# 25            26         1
# 26            27         0
# 27            28         0
# 28            29         1
# 29            30         0
# 30            31         0
# 31            32         1
# 32            33         1
# ...

# %%
title_mapping = {"Mr": 1, "Miss": 2, "Mrs": 3, "Master": 4, "Royal": 5, "Rare": 6}
for df in combine:
    df['PassengerId'] = df['PassengerId'].map(title_mapping)
    df['PassengerId'] = df['PassengerId'].fillna(0)

train
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# 5              6         0      3
# 6              7         0      1
# 7              8         0      3
# 8              9         1      3
# 9             10         1      2
# 10            11         1      3
# 11            12         1      1
# 12            13         0      3
# 13            14         0      3
# 14            15         0      3
# 15            16         1      2
# 16            17         0      3
# 17            18         1      2
# 18            19         0      3
# 19            20         1      3
# 20            21         0      2
# 21            22         1      2
# 22            23         1      3
# 23            24         1      1
# 24            25         0      3
# 25            26         1      3
# ...

# %%
mr_age = df[df["PassengerId"] == 1]["Age"].mode() 
miss_age = df[df["PassengerId"] == 2]["Age"].mode() 
mrs_age = df[df["PassengerId"] == 3]["Age"].mode() 
master_age = df[df["PassengerId"] == 4]["Age"].mode()
royal_age = df[df["PassengerId"] == 5]["Age"].mode() 
rare_age = df[df["PassengerId"] == 6]["Age"].mode()

pd.get_dummies('Age')
# Out:
#    Age
# 0    1

# %%
age_title_mapping = {1: "Young Adult", 2: "Student", 3: "Adult", 4: "Baby", 5: "Adult", 6: "Adult"}

# %%
age_mapping = {'Baby': 1, 'Child': 2, 'Teenager': 3, 'Student': 4, 'Young Adult': 5, 'Adult': 6, 'Senior': 7}
train['Age'] = train['Age'].map(age_mapping)
test['Age'] = test['Age'].map(age_mapping)

train
# Out:
#      PassengerId  Survived Pclass  \
# 0              1         0      3
# 1              2         1      1
# 2              3         1      3
# 3              4         1      1
# 4              5         0      3
# 5              6         0      3
# 6              7         0      1
# 7              8         0      3
# 8              9         1      3
# 9             10         1      2
# 10            11         1      3
# 11            12         1      1
# 12            13         0      3
# 13            14         0      3
# 14            15         0      3
# 15            16         1      2
# 16            17         0      3
# 17            18         1      2
# 18            19         0      3
# 19            20         1      3
# 20            21         0      2
# 21            22         1      2
# 22            23         1      3
# 23            24         1      1
# 24            25         0      3
# 25            26         1      3
# ...

# %%
x = df.drop(['Name'], axis = 1)
y = df.drop(['Name'], axis = 1)

# %%
sex_mapping = {"male": 0, "female": 1}
train['Sex'] = train['Sex'].map(sex_mapping)
test['Sex'] = test['Sex'].map(sex_mapping)

train.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  NaN      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  NaN      1      0
# 2                             Heikkinen, Miss. Laina    1  NaN      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  NaN      1      0
# 4                           Allen, Mr. William Henry    0  NaN      0      0
#
#              Ticket     Fare  ... Cabin_values  Cabin_2 ticket_num  \
# 0         A/5 21171   7.2500  ...            0        n          0
# 1          PC 17599  71.2833  ...            1        C          0
# 2  STON/O2. 3101282   7.9250  ...            0        n          0
# ...

# %%
embarked_mapping = {"S": 1, "C": 2, "Q": 3}
train['Embarked'] = train['Embarked'].map(embarked_mapping)
test['Embarked'] = test['Embarked'].map(embarked_mapping)

train.head()
# Out:
#    PassengerId  Survived Pclass  \
# 0            1         0      3
# 1            2         1      1
# 2            3         1      3
# 3            4         1      1
# 4            5         0      3
#
#                                                 Name  Sex  Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    0  NaN      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1  NaN      1      0
# 2                             Heikkinen, Miss. Laina    1  NaN      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  NaN      1      0
# 4                           Allen, Mr. William Henry    0  NaN      0      0
#
#              Ticket     Fare  ...  Cabin_values  Cabin_2 ticket_num  \
# 0         A/5 21171   7.2500  ...             0        n          0
# 1          PC 17599  71.2833  ...             1        C          0
# 2  STON/O2. 3101282   7.9250  ...             0        n          0
# ...

# %%
from sklearn.model_selection import train_test_split

predictors = train.drop(['Survived', 'PassengerId','Name','Ticket','Cabin_adv','Cabin_2','ticket_letters','Names','name_title','Age'], axis=1)
target = train["Survived"]
x_train, x_val, y_train, y_val = train_test_split(predictors, target, test_size = 0.22, random_state = 0)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gaussian = GaussianNB()
gaussian.fit(x_train, y_train)
y_pred = gaussian.predict(x_val)
acc_gaussian = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gaussian)
# Out:
# 69.9

# %%
from sklearn.linear_model import LogisticRegression

logreg = LogisticRegression()
logreg.fit(x_train, y_train)
y_pred = logreg.predict(x_val)
acc_logreg = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_logreg)
# Out:
# 74.49

# %%
from sklearn.svm import SVC

svc = SVC()
svc.fit(x_train, y_train)
y_pred = svc.predict(x_val)
acc_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_svc)
# Out:
# 62.76

# %%
from sklearn.svm import LinearSVC

linear_svc = LinearSVC()
linear_svc.fit(x_train, y_train)
y_pred = linear_svc.predict(x_val)
acc_linear_svc = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_linear_svc)
# Out:
# 72.45

# %%
from sklearn.linear_model import Perceptron

perceptron = Perceptron()
perceptron.fit(x_train, y_train)
y_pred = perceptron.predict(x_val)
acc_perceptron = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_perceptron)
# Out:
# 70.41

# %%
from sklearn.tree import DecisionTreeClassifier

decisiontree = DecisionTreeClassifier()
decisiontree.fit(x_train, y_train)
y_pred = decisiontree.predict(x_val)
acc_decisiontree = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_decisiontree)
# Out:
# 73.98

# %%
from sklearn.ensemble import RandomForestClassifier

randomforest = RandomForestClassifier()
randomforest.fit(x_train, y_train)
y_pred = randomforest.predict(x_val)
acc_randomforest = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_randomforest)
# Out:
# 75.51

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)
y_pred = knn.predict(x_val)
acc_knn = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_knn)
# Out:
# 70.41

# %%
from sklearn.linear_model import SGDClassifier

sgd = SGDClassifier()
sgd.fit(x_train, y_train)
y_pred = sgd.predict(x_val)
acc_sgd = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_sgd)
# Out:
# 60.71

# %%
from sklearn.ensemble import GradientBoostingClassifier

gbk = GradientBoostingClassifier()
gbk.fit(x_train, y_train)
y_pred = gbk.predict(x_val)
acc_gbk = round(accuracy_score(y_pred, y_val) * 100, 2)
print(acc_gbk)
# Out:
# 75.0

# %%
models = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 'Linear SVC', 
              'Decision Tree', 'Stochastic Gradient Descent', 'Gradient Boosting Classifier'],
    'Score': [acc_svc, acc_knn, acc_logreg, 
              acc_randomforest, acc_gaussian, acc_perceptron,acc_linear_svc, acc_decisiontree,
              acc_sgd, acc_gbk]})
models.sort_values(by='Score', ascending=False)
# Out:
#                           Model  Score
# 3                 Random Forest  75.51
# 9  Gradient Boosting Classifier  75.00
# 2           Logistic Regression  74.49
# 7                 Decision Tree  73.98
# 6                    Linear SVC  72.45
# 1                           KNN  70.41
# 5                    Perceptron  70.41
# 4                   Naive Bayes  69.90
# 0       Support Vector Machines  62.76
# 8   Stochastic Gradient Descent  60.71

# %%
import joblib

# %%
joblib.dump(models,'Titanic.pkl')
# Out:
# ['Titanic.pkl']
